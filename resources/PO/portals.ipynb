# %%
*** Settings ***
Documentation     A resource file with reusable keywords and variables.
...
...               The system specific keywords created here form our own
...               domain specific language. They utilize keywords provided
...               by the imported SeleniumLibrary.
Library           SeleniumLibrary
Library           OperatingSystem
Library           String


*** Variables ***
${VALID_SERVER}         alias-selfcare-aliasnumbers-valid.kermit-noprod-b.itn.intraorange
${BROWSER}        headlessfirefox
${DELAY}          7

${LOGIN_URL}      https://${VALID_SERVER}/login
${HOME URL}    https://${VALID_SERVER}/routes/active
${ERROR URL}      https://${VALID_SERVER}/error

${page_title}    Alias Numbers Administration
${header_title}    Authentification AliasNumbers

${login_error_message}    Login et/ou mot de passe erron\u00E9
${username_error_message}    Le login est obligatoire
${password_error_message}     Le mot de passe est obligatoire    

${button_text}     Connexion
${routes_title}    Routes
    
#############################################################
${ADMIN_URL_VALID}	https://10.170.203.6/vnumbers-admin-api/api/v4
${ALIAS_URL_VALID}	https://10.170.203.6/vnumbers-aliasnumbers-api/api/v4
${PRIVATE_API_AUTH}	Basic cG9ydGFsQWRtaW46IWFsaWFzTnVtYmVyMjAxNQ==

${ALIAS_URL_PUBLIC}	https://10.170.203.6/vnumbers-aliasnumbers-api/api/v4/public
${ADMIN_URL_PRIVATE}	${ADMIN_URL_VALID}/private
${ALIAS_URL_PRIVATE}	${ALIAS_URL_VALID}/private

${ApplicationId}	aaaaaaaaaaaaaaaa
${Application-name}	RDT_Calls
${ServiceId}	d15c4910-d6a5-40f8-a556-0540d97f64d8
${contextId}	8c57c952-05bc-45b0-8965-d2d8c022d205
${TECHNICIAN_NUMBER}	+33785969593
${ALIAS_NUMBER}	+33785969593
${Zone-Id}	PPE
${Authorization}	Bearer ju8ZEelfpLXlU681SoEBCTNxqPuT
${Content-Type}	application/json

##################routes page##################################

${VALID_USER}     admin
${VALID_PASSWORD}    test
${Invalid_USER}     admins
${Invalid_PASSWORD}    tests
${Empty_USER}     ${EMPTY}
${Empty_PASSWORD}    ${EMPTY}


${button_routes_text}     Cr\u00E9er 
${button_routes_validate}    Valider


${client}    0612356897   
${alias}     +3300
${counselor}    France Piraud    
${comment}    test automation

${route_sucess_message}    Nouvelle route cr\u00E9\u00E9e    

${exp_comment}    ${EMPTY}



*** Keywords ***
The Browser Is Opened To Login Page
    Open Browser    ${LOGIN URL}    ${BROWSER}
    Maximize Browser Window
    Set Selenium Speed    ${DELAY}
    Login Page Should Be Open

Login Page Should Be Open
    Title Should Be    ${page_title}    
    Page Should Contain Element    //h3[text()='${header_title}']

Go To Login Page
    Go To    ${LOGIN URL}
    Login Page Should Be Open

A ${username} Username and ${password} Credentials Is Used
    Wait Until Element Is Visible    userName
    Input Text    userName    ${username}
    Wait Until Element Is Visible    password    
    Input Text    password    ${password}

Credentials Is Submitted
    Wait Until Element Is Visible    //button[contains(text(),'${button_text}')]
    Click Button    //button[contains(text(),'${button_text}')]

Routes Page Should Be Opened
    Location Should Be    ${HOME URL}
    Wait Until Element Is Visible    //h1[text()='${routes_title}']
    Element Should Be Visible    //h1[text()='${routes_title}']
    
Login Error Message Should Be Displayed
    ${src}=    Get Source
    ${lines} = 	Get Lines Containing String 	${src} 	${login_error_message}
    Log    ${lines}

User name Error Message Should Be Displayed
    ${src}=    Get Source
    ${lines} = 	Get Lines Containing String 	${src} 	${username_error_message}
    Log    ${lines}

Password Error Message Should Be Displayed
    ${src}=    Get Source
    ${lines} = 	Get Lines Containing String 	${src} 	${password_error_message}
    Log    ${lines}

Login Button is Not Enabled
    Element Should Be Disabled    //button[text()='${button_text}']    
    
Routes Page Is Displayed 
    Wait Until Element Is Visible    //h1[text()='${routes_title}']
    Location Should Be    ${HOME URL}    
    Element Should Be Visible    //h1[text()='${routes_title}']

The User Is LoggedIn
    The Browser Is Opened To Login Page
    A ${VALID_USER} Username and ${VALID_PASSWORD} Credentials Is Used
    Credentials Is Submitted
    Routes Page Should Be Opened

Click Route Button
    Click Button    //button[contains(text(),'${button_routes_text}')] 

Add ${client} Number
    Input Text    callerNumber    ${client}

Select Counselor Number
    Click Element    //select[@id='externalNumbersList']
    Click Element    //option[@value='${alias}']    

Add A ${comment}
    Input Text    note    ${comment}

Press Validate Button
    Click Button    //button[@class='btn btn-success']

Add A Route 
    Click Route Button
	Add ${client} Number
	Select Counselor Number
	Add A ${comment}
    Press Validate Button

A Route Is Added   
    Add A Route


Route Addition Success Message Should Be Displayed
    ${src}=    Get Source
    ${lines} = 	Get Lines Containing String 	${src} 	${route_sucess_message}
    Log    ${lines}


Page Filter Is Changed to ${value}
    [documentation]    add a value from 1 to 5 to change the pagination
    Click Button    //select[@id='nbPerPage']
    Click Element    //option[@value='${value}']    
    

Press Edit Button
    Click Button    //tr[3]//td[8]//button[1]

Client Number Field Should be Disabled
    Element Should Be Disabled    //input[@id='callerNumber']
Alias number Field Should be Disabled
    Element Should Be Disabled    //input[@id='aliasNumber']
User number Field Should be Disabled
    Element Should Be Disabled    //input[@id='userNumber']

Table Routes Count
    ${count}=    Get Element Count    //body//tbody//tr
    [return]    ${count}
    
Get Routes Count from page
    ${text1}=    Get Text    //app-routes[1]/div[4]/div[1]/b[1]
    ${text2}=   Get Substring 	${text1} 	25 	 
    [return]    ${text2}

Page Count and Added Routes Should Be Equal
    ${number1}=    Table Routes Count
    ${number2}=    Get Routes Count from page
    Should Be Equal As Numbers    ${number1}    ${number2}   

Tooltip Should Appear With The Correct Deletion Date
    Mouse Over    css=div.header-status-btn[title="Restore the header"]
	# wait up to 60s for element to become visible
	Wait Until Element Is Visible    css=div.logo.float-header
    ${text1}=    Get Text    //app-routes[1]/div[4]/div[1]/b[1]
    
Get Text from Comment Tab
    ${text1}=    Get Text    //td[contains(text(),'test automation')]
        
#Press Edit Routes Button

Add Multiple Routes
    FOR    ${INDEX}    IN RANGE    1    101
    Add A Route
    END        
    Log    For loop is over

A Route Exists
    ${actual_comment}=     Get Text    //td  
    Should Be Equal As Strings    ${exp_comment}    ${actual_comment}   
    
    
Logout Dropdown Is Pressed
    Click Element    //button[@id='dropdownUserMenu']
    Click Element    //div[@class='dropdown-menu show']

Back Button Is Pressed
    Sleep    3
    Go Back    
    
    
    
    
Delete Voicemail Message
	[Arguments]  ${authorizationtoken}    ${zoneid}    ${serviceID}    ${applicationid}    ${voicemailid}    ${responsecode}    ${code}=${EMPTY}    ${message}=${EMPTY}    ${voicemailstatus}=${EMPTY}
    Create Session  delvmail  ${ALIAS_URL_PUBLIC}    disable_warnings=1
    ${headers}=  Create Dictionary  Authorization=${authorizationtoken}    X-VNumbers-Zone-Id=${zoneid}
    ...    X-VNumbers-Service-Id=${serviceID}    X-OAPI-Application-Id=${applicationid}
    ${resp}=  Delete Request  delvmail    /voicemails/${voicemailid}    headers=${headers}
    Log    ${resp}
    Should Be Equal As Strings    ${resp.status_code}    ${responsecode}
    Run Keyword If 	'${resp.status_code}' == '204'    Should Be Empty    ${resp}
    ...    ELSE   Run Keywords    Should Be Equal As Strings    ${resp.status_code}    ${responsecode}
    ...    AND    Should Be Equal As Strings    ${resp.json()["code"]}    ${code}
    ...    AND    Should Be Equal As Strings    ${resp.json()["message"]}    ${message}
